# %% [markdown]
# # HeroX Numerical Fact Checking System. Univeristy of Sheffield
#
# Pre-requisites:
#  * Gradle
#  * Java jdk8
#  * Python 3
#   * jnius
#   * fuzzywuzzy
#   * sklearn
#   * urllib3

# %%
import sys
import os
import re

#Set path manually to incldue sources location
if 'src/' not in sys.path:
    sys.path.append('src/')

# %%
#Load Java classpath for stanford corenlp using gradle. this will also install it if missing
from subprocess import run,PIPE
if 'CLASSPATH' not in os.environ:
    if not (os.path.exists('build') and os.path.exists('build/classpath.txt')):
        print("Generating classpath")
        r=run(["./gradlew", "writeClasspath"],stdout=PIPE, stderr=PIPE, universal_newlines=True)
        print(r.stdout)
        print(r.stderr)
              
    print("Loading classpath")
    os.environ['CLASSPATH'] = open('build/classpath.txt','r').read()
    print("Done")

# %%
from classifier.LogisticRegressionClassifier import LogisticRegressionClassifier
from classifier.features.generate_features import FeatureGenerator, num, is_num
from distant_supervision.utterance_detection import f_threshold_match
from factchecking.question import Question
from tabular.filtering import load_collection

# %%
fg = FeatureGenerator()
Xs,ys = fg.generate_training()
# Out:
# Done: 0.0
# Search for "Exxon Mobil" "Market Value"
# Query already executed
# Done: 6.25
# Search for "Unaccompanied children" "claimed asylum"
# Query already executed
# Done: 12.5
# Search for "Hamas" "Founded"
# Query already executed
# Done: 18.75
# Search for "United States" "Average Temperature"
# Query already executed
# Done: 25.0
# Search for "United States" "Life expectancy"
# Query already executed
# Done: 31.25
# Search for "United States" "Number of abortions"
# Query already executed
# Done: 37.5
# Search for "United States" "Abortion Rate per 1,000 births"
# Query already executed
# Done: 43.75
# Search for "United States Teenagers" "Percentage Enrolled in education"
# Query already executed
# Done: 50.0
# Search for "United States Teenagers" "Enrolled in education"
# Query already executed
# Done: 56.25
# Search for "America" "bee colonies 201"
# Query already executed
# Done: 62.5
# Search for "United States" "Financial Intermediary Funds 2016"
# Query already executed
# Done: 68.75
# Search for "United States" "Homocides by firearm"
# Query already executed
# Done: 75.0
# Search for "United Kingdom" "Educated at grammar schools 2016"
# Query already executed
# Done: 81.25
# Search for "USA" "Measles Vaccination Rate"
# Query already executed
# Done: 87.5
# Search for "USA" "Practicing doctors per 1000"
# Query already executed
# Done: 93.75
# Search for "USA" "Daily Smokers 2014"
# Query already executed
# Registering words in BOW
# Registering columns
# Counting features
# Total positive: 54
# Total negative: 3278
# Looking for positive features
# 0
# Subsampling negative features
# 0

# %%
classifier = LogisticRegressionClassifier()
classifier.train(Xs,ys)
# Out:
# Training classifier
# Trained

# %%
tables = load_collection("herox")
# Out:
# register table herox/1.csv
# register table herox/2.csv
# register table herox/3.csv
# register table herox/4.csv
# register table herox/5.csv
# register table herox/8.csv
# register table herox/9.csv
# register table herox/10.csv
# register table herox/11.csv
# register table herox/12.csv
# register table herox/13.csv
# register table herox/14.csv

# %%
def fact_check(q):
    question = Question(text=q, type="NUM")
    tuples,q_features = fg.generate_test(tables,question)

    q_match = False

    if len(tuples)>0:
    
        
        
        q_predicted = classifier.predict(q_features)

        for i in range(len(tuples)):
            tuple = tuples[i]
            
            skip = False
            if len(tuple[1]['date']) and len(question.dates):
                for date in question.dates:
                    dstrs = set()
                    for d in question.dates:
                        dstrs.add(str(d))
                    if not len(set(tuple[1]['date']).intersection(dstrs)):
                        skip = True
                        
            if skip:
                continue
    

            if is_num(tuple[1]['value']):
                prediction = q_predicted[i]
                features = q_features[i]

                if prediction == 1:
                    print(str(tuple) + "\t\t" + ("Possible Match" if prediction else "No match"))
                    for number in question.numbers:
                        value = num(tuple[1]['value'])

                        if value is None:
                            continue

                        if f_threshold_match(number, value, 0.05):
                            print(str(tuple) + "\t\t" + "Threshold Match to 5%")
                            q_match = True

                    for number in question.dates:
                        value = num(tuple[1]['value'])
                        if number == value:
                            print(str(tuple) + "\t\t" + "Exact Match")
                            q_match = True
        print(question.text)
        print(q_match)

    else:
        print(question.text)
        print("No supporting information can be found in the knowledge base")
    print("\n\n")
    
fact_check("Around 90,000 unaccompanied children claimed asylum in the EU in 2015")
# Out:
# unaccompanied children
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# the EU
# asylum
# 90,000
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# EU
# 2015
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# Around 90,000 unaccompanied children claimed asylum in the EU in 2015
# False

# %%
fact_check("Around 90,000 unaccompanied children claimed asylum in the EU in 2015")
# Out:
# unaccompanied children
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# the EU
# asylum
# 90,000
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# ['Asylum applicants considered to be unaccompanied minors']
# EU
# 2015
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'Former Yugoslav Republic of Macedonia, the', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': ':'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2008'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11695'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2009'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12190'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2010'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '10610'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2011'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '11690'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2012'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12540'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2013'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '12725'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2014'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '23150'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})
# ('herox/2.csv', {'entity': 'EU (28 countries)', 'date': ['2015'], 'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '96465'})		Possible Match
# Around 90,000 unaccompanied children claimed asylum in the EU in 2015
# False

# %%
import csv
import numpy as np
import re
from stanford.corenlpy import * 

def read_table(filename,base="data/WikiTableQuestions"):
    header = []
    rows = []

    header_read = False
    filename = filename.replace(".csv",".tsv")
    with open(base+"/"+filename,"r",encoding='utf-8') as table:
        has_header = csv.Sniffer().has_header(table.readline())
        table.seek(0)

        for line in csv.reader(table, delimiter="\t"):
            if has_header and not header_read:
                header = line
                header_read = True
            else:
                rows.append(line)
    return {"header": header, "rows":rows}

def table_nes(table):
    header = table['header']
    rows = table['rows']

    ret_tokens = []
    for col in transpose(rows):
        text = ". ".join(col)
        doc = Annotation(text)
        SharedNERPipeline().getInstance().annotate(doc)


        num_ne_cell = 0
        tokens = []
        for cell in range(doc.get(CoreAnnotations.SentencesAnnotation).size()):
            col = doc.get(CoreAnnotations.SentencesAnnotation).get(cell)

            words = []
            col_ne_tags = []
            has_ne = False
            for i in range(col.get(CoreAnnotations.TokensAnnotation).size()):
                corelabel = col.get(CoreAnnotations.TokensAnnotation).get(i)
                ne =corelabel.get(CoreAnnotations.NamedEntityTagAnnotation)

                words.append(corelabel.get(CoreAnnotations.TextAnnotation))
                if ne not in ['O','NUMBER','NUMERIC']:
                    has_ne = True

            if len(words) > 1:
                tokens.append(" ".join(words[:-1]))

            if has_ne:
                num_ne_cell += 1

        if num_ne_cell >= len(tokens)/2 and len(tokens) > 0:
            ret_tokens.extend(tokens)

    return ret_tokens


def number_tuples(table):
    header = table['header']
    rows = table['rows']

    ret_tokens = []
    entity_col = []
    date_col = []
    number_col = []

    col_id = 0

    table_trans = transpose(rows)

    hnums = set()
    hidx = 0
    for h in header:
        doc = Annotation(h)
        SharedNERPipeline().getInstance().annotate(doc)

        for s in range(doc.get(CoreAnnotations.SentencesAnnotation).size()):
            c = doc.get(CoreAnnotations.SentencesAnnotation).get(s)
            for i in range(c.get(CoreAnnotations.TokensAnnotation).size()):
                corelabel = c.get(CoreAnnotations.TokensAnnotation).get(i)
                ne = corelabel.get(CoreAnnotations.NamedEntityTagAnnotation)

                if ne in ['YEAR', 'DATE']:
                    hnums.add(hidx)
        hidx += 1

    hseries = False
    if (len(hnums) >= len(header) / 2):
        hseries = True

        
    num_nes = []
    num_dates = []
    num_numbers = []
    
    all_tokens = []
    for col in table_trans:

        text = ". ".join(col)
        doc = Annotation(text)
        SharedNERPipeline().getInstance().annotate(doc)

        num_ne_cell = 0
        num_date_cell = 0
        num_number_cell = 0

        tokens = []
        for cell in range(doc.get(CoreAnnotations.SentencesAnnotation).size()):
            col = doc.get(CoreAnnotations.SentencesAnnotation).get(cell)

            words = []
            col_ne_tags = []
            has_ne = False
            has_date = False
            has_number = False
            for i in range(col.get(CoreAnnotations.TokensAnnotation).size()):
                corelabel = col.get(CoreAnnotations.TokensAnnotation).get(i)
                ne = corelabel.get(CoreAnnotations.NamedEntityTagAnnotation)

                words.append(corelabel.get(CoreAnnotations.TextAnnotation))
                if ne not in ['O', 'NUMBER', 'NUMERIC', 'DATE', 'YEAR']:
                    has_ne = True

                if ne in ['YEAR', 'DATE']:
                    has_date = True

                if ne in ['NUMBER', 'NUMERIC', 'PERCENTAGE', 'ORDINAL']:
                    has_number = True

            if len(words) > 0:
                tokens.append(" ".join(words[:-1]))

            
            if has_ne:
                num_ne_cell += 1

            if has_date:
                num_date_cell += 1

            if has_number:
                num_number_cell += 1
                
        num_nes.append(num_ne_cell)
        num_dates.append(num_date_cell)
        num_numbers.append(num_number_cell)
        all_tokens.append(tokens)
        

    
    col_id = 0
    for col in table_trans:     
        if num_nes[col_id] >= len(all_tokens[col_id]) / 2 and len(all_tokens[col_id]) > 0:
            entity_col.append(col_id)
        col_id += 1
   

    col_id = 0
    for col in table_trans:     
        if len(entity_col) and num_dates[col_id] >= len(all_tokens[col_id]) / 2 and len(all_tokens[col_id]) >0:
            if col_id < max(entity_col) and  col_id > min(entity_col):
                number_col.append(col_id)
            else:
                date_col.append(col_id)

        if num_numbers[col_id] >= len(all_tokens[col_id]) / 2:
            number_col.append(col_id)
        col_id += 1

    tuples = []


    if not hseries:
        for col in entity_col:
            for col1 in number_col:
                if col1 in entity_col: 
                    continue
                if col in number_col:
                    continue
                    
                extra = []
                if len(date_col) > 0:
                    for dc in date_col:
                        extra.append(table_trans[dc])
                    extra = transpose(extra)
                # TODO entity/relation/value

                for i in range(len(rows)):
                    t = dict()
                    t['relation'] = header[col1]
                    t['value'] = table_trans[col1][i]
                    t['entity'] = table_trans[col][i]

                    if len(extra):
                        t['date'] = extra[i]
                    tuples.append(t)

    else:

        extra = []
        hnums = list(hnums)

        nh = (set(range(len(header))).difference(hnums))
        tr = []
        for col in nh:
            if col not in entity_col:
                extra.append(table_trans[col])
        el = len(extra)
        extra = transpose(extra)

        for hnum in hnums:
            for ecol in entity_col:
                l = list(zip([header[hnum]] * len(rows), table_trans[hnum], extra))
                i=0
                for t in l:
                    for rel in t[2:][0]:
                        t2 = dict()

                        t2['entity'] = table_trans[ecol][i]
                        t2['relation'] = rel
                        for item in t[0:1]:
                            if 'date' not in t2:
                                t2['date'] = []
                            t2['date'].append(item)

                        t2['value'] = t[1]

                        tuples.append(t2)
                    i+=1

    return tuples


def transpose(l):
    return list(map(list, zip(*l)))


b = 5
for tnum in range(b,b+1):
    print(tnum)
    t = read_table("herox/"+str(tnum)+".csv")
    tuples = number_tuples(t)

    for tuple in tuples:
        print(tuple)
# Out:
# 5
# {'entity': 'Aruba', 'date': ['1960'], 'relation': 'ABW', 'value': '65.56936585'}
# {'entity': 'Aruba', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '65.56936585'}
# {'entity': 'Andorra', 'date': ['1960'], 'relation': 'AND', 'value': ''}
# {'entity': 'Andorra', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Afghanistan', 'date': ['1960'], 'relation': 'AFG', 'value': '32.3285122'}
# {'entity': 'Afghanistan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '32.3285122'}
# {'entity': 'Angola', 'date': ['1960'], 'relation': 'AGO', 'value': '32.98482927'}
# {'entity': 'Angola', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '32.98482927'}
# {'entity': 'Albania', 'date': ['1960'], 'relation': 'ALB', 'value': '62.25436585'}
# {'entity': 'Albania', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '62.25436585'}
# {'entity': 'Arab World', 'date': ['1960'], 'relation': 'ARB', 'value': '46.8500222'}
# {'entity': 'Arab World', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.8500222'}
# {'entity': 'United Arab Emirates', 'date': ['1960'], 'relation': 'ARE', 'value': '52.24321951'}
# {'entity': 'United Arab Emirates', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '52.24321951'}
# {'entity': 'Argentina', 'date': ['1960'], 'relation': 'ARG', 'value': '65.21553659'}
# {'entity': 'Argentina', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '65.21553659'}
# {'entity': 'Armenia', 'date': ['1960'], 'relation': 'ARM', 'value': '65.86346341'}
# {'entity': 'Armenia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '65.86346341'}
# {'entity': 'American Samoa', 'date': ['1960'], 'relation': 'ASM', 'value': ''}
# {'entity': 'American Samoa', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Antigua and Barbuda', 'date': ['1960'], 'relation': 'ATG', 'value': '61.78273171'}
# {'entity': 'Antigua and Barbuda', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '61.78273171'}
# {'entity': 'Australia', 'date': ['1960'], 'relation': 'AUS', 'value': '70.81707317'}
# {'entity': 'Australia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '70.81707317'}
# {'entity': 'Austria', 'date': ['1960'], 'relation': 'AUT', 'value': '68.58560976'}
# {'entity': 'Austria', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.58560976'}
# {'entity': 'Azerbaijan', 'date': ['1960'], 'relation': 'AZE', 'value': '60.8362439'}
# {'entity': 'Azerbaijan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.8362439'}
# {'entity': 'Burundi', 'date': ['1960'], 'relation': 'BDI', 'value': '41.23604878'}
# {'entity': 'Burundi', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.23604878'}
# {'entity': 'Belgium', 'date': ['1960'], 'relation': 'BEL', 'value': '69.70195122'}
# {'entity': 'Belgium', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.70195122'}
# {'entity': 'Benin', 'date': ['1960'], 'relation': 'BEN', 'value': '37.27826829'}
# {'entity': 'Benin', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '37.27826829'}
# {'entity': 'Burkina Faso', 'date': ['1960'], 'relation': 'BFA', 'value': '34.47790244'}
# {'entity': 'Burkina Faso', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '34.47790244'}
# {'entity': 'Bangladesh', 'date': ['1960'], 'relation': 'BGD', 'value': '45.82931707'}
# {'entity': 'Bangladesh', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.82931707'}
# {'entity': 'Bulgaria', 'date': ['1960'], 'relation': 'BGR', 'value': '69.24756098'}
# {'entity': 'Bulgaria', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.24756098'}
# {'entity': 'Bahrain', 'date': ['1960'], 'relation': 'BHR', 'value': '52.08936585'}
# {'entity': 'Bahrain', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '52.08936585'}
# {'entity': 'Bahamas, The', 'date': ['1960'], 'relation': 'BHS', 'value': '62.72904878'}
# {'entity': 'Bahamas, The', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '62.72904878'}
# {'entity': 'Bosnia and Herzegovina', 'date': ['1960'], 'relation': 'BIH', 'value': '60.27621951'}
# {'entity': 'Bosnia and Herzegovina', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.27621951'}
# {'entity': 'Belarus', 'date': ['1960'], 'relation': 'BLR', 'value': '67.70809756'}
# {'entity': 'Belarus', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.70809756'}
# {'entity': 'Belize', 'date': ['1960'], 'relation': 'BLZ', 'value': '59.96136585'}
# {'entity': 'Belize', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '59.96136585'}
# {'entity': 'Bermuda', 'date': ['1960'], 'relation': 'BMU', 'value': ''}
# {'entity': 'Bermuda', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Bolivia', 'date': ['1960'], 'relation': 'BOL', 'value': '42.11831707'}
# {'entity': 'Bolivia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '42.11831707'}
# {'entity': 'Brazil', 'date': ['1960'], 'relation': 'BRA', 'value': '54.20546341'}
# {'entity': 'Brazil', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '54.20546341'}
# {'entity': 'Barbados', 'date': ['1960'], 'relation': 'BRB', 'value': '60.73804878'}
# {'entity': 'Barbados', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.73804878'}
# {'entity': 'Brunei Darussalam', 'date': ['1960'], 'relation': 'BRN', 'value': '62.50036585'}
# {'entity': 'Brunei Darussalam', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '62.50036585'}
# {'entity': 'Bhutan', 'date': ['1960'], 'relation': 'BTN', 'value': '32.35936585'}
# {'entity': 'Bhutan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '32.35936585'}
# {'entity': 'Botswana', 'date': ['1960'], 'relation': 'BWA', 'value': '50.54773171'}
# {'entity': 'Botswana', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '50.54773171'}
# {'entity': 'Central African Republic', 'date': ['1960'], 'relation': 'CAF', 'value': '36.48263415'}
# {'entity': 'Central African Republic', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '36.48263415'}
# {'entity': 'Canada', 'date': ['1960'], 'relation': 'CAN', 'value': '71.13317073'}
# {'entity': 'Canada', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '71.13317073'}
# {'entity': 'Central Europe and the Baltics', 'date': ['1960'], 'relation': 'CEB', 'value': '67.82376209'}
# {'entity': 'Central Europe and the Baltics', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.82376209'}
# {'entity': 'Switzerland', 'date': ['1960'], 'relation': 'CHE', 'value': '71.31341463'}
# {'entity': 'Switzerland', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '71.31341463'}
# {'entity': 'Channel Islands', 'date': ['1960'], 'relation': 'CHI', 'value': '70.63978049'}
# {'entity': 'Channel Islands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '70.63978049'}
# {'entity': 'Chile', 'date': ['1960'], 'relation': 'CHL', 'value': '57.45829268'}
# {'entity': 'Chile', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '57.45829268'}
# {'entity': 'China', 'date': ['1960'], 'relation': 'CHN', 'value': '43.354'}
# {'entity': 'China', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '43.354'}
# {'entity': "Cote d'Ivoire", 'date': ['1960'], 'relation': 'CIV', 'value': '36.87241463'}
# {'entity': "Cote d'Ivoire", 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '36.87241463'}
# {'entity': 'Cameroon', 'date': ['1960'], 'relation': 'CMR', 'value': '41.5237561'}
# {'entity': 'Cameroon', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.5237561'}
# {'entity': 'Congo, Rep.', 'date': ['1960'], 'relation': 'COG', 'value': '48.58163415'}
# {'entity': 'Congo, Rep.', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.58163415'}
# {'entity': 'Colombia', 'date': ['1960'], 'relation': 'COL', 'value': '56.7167561'}
# {'entity': 'Colombia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '56.7167561'}
# {'entity': 'Comoros', 'date': ['1960'], 'relation': 'COM', 'value': '41.44243902'}
# {'entity': 'Comoros', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.44243902'}
# {'entity': 'Cabo Verde', 'date': ['1960'], 'relation': 'CPV', 'value': '48.85641463'}
# {'entity': 'Cabo Verde', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.85641463'}
# {'entity': 'Costa Rica', 'date': ['1960'], 'relation': 'CRI', 'value': '60.57619512'}
# {'entity': 'Costa Rica', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.57619512'}
# {'entity': 'Caribbean small states', 'date': ['1960'], 'relation': 'CSS', 'value': '62.3182116'}
# {'entity': 'Caribbean small states', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '62.3182116'}
# {'entity': 'Cuba', 'date': ['1960'], 'relation': 'CUB', 'value': '63.90465854'}
# {'entity': 'Cuba', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '63.90465854'}
# {'entity': 'Curacao', 'date': ['1960'], 'relation': 'CUW', 'value': ''}
# {'entity': 'Curacao', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Cayman Islands', 'date': ['1960'], 'relation': 'CYM', 'value': ''}
# {'entity': 'Cayman Islands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Cyprus', 'date': ['1960'], 'relation': 'CYP', 'value': '69.59392683'}
# {'entity': 'Cyprus', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.59392683'}
# {'entity': 'Czech Republic', 'date': ['1960'], 'relation': 'CZE', 'value': '70.34878049'}
# {'entity': 'Czech Republic', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '70.34878049'}
# {'entity': 'Germany', 'date': ['1960'], 'relation': 'DEU', 'value': '69.31295122'}
# {'entity': 'Germany', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.31295122'}
# {'entity': 'Djibouti', 'date': ['1960'], 'relation': 'DJI', 'value': '44.02126829'}
# {'entity': 'Djibouti', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '44.02126829'}
# {'entity': 'Dominica', 'date': ['1960'], 'relation': 'DMA', 'value': ''}
# {'entity': 'Dominica', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Denmark', 'date': ['1960'], 'relation': 'DNK', 'value': '72.17658537'}
# {'entity': 'Denmark', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '72.17658537'}
# {'entity': 'Dominican Republic', 'date': ['1960'], 'relation': 'DOM', 'value': '51.84526829'}
# {'entity': 'Dominican Republic', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '51.84526829'}
# {'entity': 'Algeria', 'date': ['1960'], 'relation': 'DZA', 'value': '46.13512195'}
# {'entity': 'Algeria', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.13512195'}
# {'entity': 'East Asia & Pacific (excluding high income)', 'date': ['1960'], 'relation': 'EAP', 'value': '45.46646641'}
# {'entity': 'East Asia & Pacific (excluding high income)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.46646641'}
# {'entity': 'Early-demographic dividend', 'date': ['1960'], 'relation': 'EAR', 'value': '45.14742623'}
# {'entity': 'Early-demographic dividend', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.14742623'}
# {'entity': 'East Asia & Pacific', 'date': ['1960'], 'relation': 'EAS', 'value': '48.22677442'}
# {'entity': 'East Asia & Pacific', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.22677442'}
# {'entity': 'Europe & Central Asia (excluding high income)', 'date': ['1960'], 'relation': 'ECA', 'value': '63.3807316'}
# {'entity': 'Europe & Central Asia (excluding high income)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '63.3807316'}
# {'entity': 'Europe & Central Asia', 'date': ['1960'], 'relation': 'ECS', 'value': '67.02999509'}
# {'entity': 'Europe & Central Asia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.02999509'}
# {'entity': 'Ecuador', 'date': ['1960'], 'relation': 'ECU', 'value': '53.215'}
# {'entity': 'Ecuador', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '53.215'}
# {'entity': 'Egypt, Arab Rep.', 'date': ['1960'], 'relation': 'EGY', 'value': '48.01370732'}
# {'entity': 'Egypt, Arab Rep.', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.01370732'}
# {'entity': 'Euro area', 'date': ['1960'], 'relation': 'EMU', 'value': '69.27371101'}
# {'entity': 'Euro area', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.27371101'}
# {'entity': 'Eritrea', 'date': ['1960'], 'relation': 'ERI', 'value': '37.36290244'}
# {'entity': 'Eritrea', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '37.36290244'}
# {'entity': 'Spain', 'date': ['1960'], 'relation': 'ESP', 'value': '69.10926829'}
# {'entity': 'Spain', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.10926829'}
# {'entity': 'Estonia', 'date': ['1960'], 'relation': 'EST', 'value': '67.90597561'}
# {'entity': 'Estonia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.90597561'}
# {'entity': 'Ethiopia', 'date': ['1960'], 'relation': 'ETH', 'value': '38.40570732'}
# {'entity': 'Ethiopia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '38.40570732'}
# {'entity': 'European Union', 'date': ['1960'], 'relation': 'EUU', 'value': '69.27954395'}
# {'entity': 'European Union', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.27954395'}
# {'entity': 'Fragile and conflict affected situations', 'date': ['1960'], 'relation': 'FCS', 'value': '40.88189206'}
# {'entity': 'Fragile and conflict affected situations', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '40.88189206'}
# {'entity': 'Finland', 'date': ['1960'], 'relation': 'FIN', 'value': '68.8197561'}
# {'entity': 'Finland', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.8197561'}
# {'entity': 'Fiji', 'date': ['1960'], 'relation': 'FJI', 'value': '55.9584878'}
# {'entity': 'Fiji', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '55.9584878'}
# {'entity': 'France', 'date': ['1960'], 'relation': 'FRA', 'value': '69.86829268'}
# {'entity': 'France', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.86829268'}
# {'entity': 'Faroe Islands', 'date': ['1960'], 'relation': 'FRO', 'value': ''}
# {'entity': 'Faroe Islands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Micronesia, Fed. Sts.', 'date': ['1960'], 'relation': 'FSM', 'value': '57.58658537'}
# {'entity': 'Micronesia, Fed. Sts.', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '57.58658537'}
# {'entity': 'Gabon', 'date': ['1960'], 'relation': 'GAB', 'value': '39.57012195'}
# {'entity': 'Gabon', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '39.57012195'}
# {'entity': 'United Kingdom', 'date': ['1960'], 'relation': 'GBR', 'value': '71.12682927'}
# {'entity': 'United Kingdom', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '71.12682927'}
# {'entity': 'Georgia', 'date': ['1960'], 'relation': 'GEO', 'value': '63.43185366'}
# {'entity': 'Georgia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '63.43185366'}
# {'entity': 'Ghana', 'date': ['1960'], 'relation': 'GHA', 'value': '45.83146341'}
# {'entity': 'Ghana', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.83146341'}
# {'entity': 'Gibraltar', 'date': ['1960'], 'relation': 'GIB', 'value': ''}
# {'entity': 'Gibraltar', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Guinea', 'date': ['1960'], 'relation': 'GIN', 'value': '34.88639024'}
# {'entity': 'Guinea', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '34.88639024'}
# {'entity': 'Gambia, The', 'date': ['1960'], 'relation': 'GMB', 'value': '32.04221951'}
# {'entity': 'Gambia, The', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '32.04221951'}
# {'entity': 'Guinea-Bissau', 'date': ['1960'], 'relation': 'GNB', 'value': '37.84043902'}
# {'entity': 'Guinea-Bissau', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '37.84043902'}
# {'entity': 'Equatorial Guinea', 'date': ['1960'], 'relation': 'GNQ', 'value': '36.73304878'}
# {'entity': 'Equatorial Guinea', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '36.73304878'}
# {'entity': 'Greece', 'date': ['1960'], 'relation': 'GRC', 'value': '68.16390244'}
# {'entity': 'Greece', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.16390244'}
# {'entity': 'Grenada', 'date': ['1960'], 'relation': 'GRD', 'value': '59.81592683'}
# {'entity': 'Grenada', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '59.81592683'}
# {'entity': 'Greenland', 'date': ['1960'], 'relation': 'GRL', 'value': ''}
# {'entity': 'Greenland', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Guatemala', 'date': ['1960'], 'relation': 'GTM', 'value': '45.53163415'}
# {'entity': 'Guatemala', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.53163415'}
# {'entity': 'Guam', 'date': ['1960'], 'relation': 'GUM', 'value': '61.22634146'}
# {'entity': 'Guam', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '61.22634146'}
# {'entity': 'Guyana', 'date': ['1960'], 'relation': 'GUY', 'value': '60.27873171'}
# {'entity': 'Guyana', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.27873171'}
# {'entity': 'High income', 'date': ['1960'], 'relation': 'HIC', 'value': '68.47848214'}
# {'entity': 'High income', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.47848214'}
# {'entity': 'Hong Kong SAR, China', 'date': ['1960'], 'relation': 'HKG', 'value': '66.99970732'}
# {'entity': 'Hong Kong SAR, China', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '66.99970732'}
# {'entity': 'Honduras', 'date': ['1960'], 'relation': 'HND', 'value': '46.28831707'}
# {'entity': 'Honduras', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.28831707'}
# {'entity': 'Heavily indebted poor countries (HIPC)', 'date': ['1960'], 'relation': 'HPC', 'value': '39.56408652'}
# {'entity': 'Heavily indebted poor countries (HIPC)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '39.56408652'}
# {'entity': 'Croatia', 'date': ['1960'], 'relation': 'HRV', 'value': '64.60865854'}
# {'entity': 'Croatia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '64.60865854'}
# {'entity': 'Haiti', 'date': ['1960'], 'relation': 'HTI', 'value': '42.10009756'}
# {'entity': 'Haiti', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '42.10009756'}
# {'entity': 'Hungary', 'date': ['1960'], 'relation': 'HUN', 'value': '68.00317073'}
# {'entity': 'Hungary', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.00317073'}
# {'entity': 'IBRD only', 'date': ['1960'], 'relation': 'IBD', 'value': '48.29411673'}
# {'entity': 'IBRD only', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.29411673'}
# {'entity': 'IDA & IBRD total', 'date': ['1960'], 'relation': 'IBT', 'value': '47.43041918'}
# {'entity': 'IDA & IBRD total', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '47.43041918'}
# {'entity': 'IDA total', 'date': ['1960'], 'relation': 'IDA', 'value': '43.64062107'}
# {'entity': 'IDA total', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '43.64062107'}
# {'entity': 'IDA blend', 'date': ['1960'], 'relation': 'IDB', 'value': '47.72885514'}
# {'entity': 'IDA blend', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '47.72885514'}
# {'entity': 'Indonesia', 'date': ['1960'], 'relation': 'IDN', 'value': '48.64031707'}
# {'entity': 'Indonesia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.64031707'}
# {'entity': 'IDA only', 'date': ['1960'], 'relation': 'IDX', 'value': '41.08621705'}
# {'entity': 'IDA only', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.08621705'}
# {'entity': 'Isle of Man', 'date': ['1960'], 'relation': 'IMN', 'value': ''}
# {'entity': 'Isle of Man', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'India', 'date': ['1960'], 'relation': 'IND', 'value': '41.17195122'}
# {'entity': 'India', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.17195122'}
# {'entity': 'Not classified', 'date': ['1960'], 'relation': 'INX', 'value': ''}
# {'entity': 'Not classified', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Ireland', 'date': ['1960'], 'relation': 'IRL', 'value': '69.6917561'}
# {'entity': 'Ireland', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.6917561'}
# {'entity': 'Iran, Islamic Rep.', 'date': ['1960'], 'relation': 'IRN', 'value': '44.9455122'}
# {'entity': 'Iran, Islamic Rep.', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '44.9455122'}
# {'entity': 'Iraq', 'date': ['1960'], 'relation': 'IRQ', 'value': '48.03068293'}
# {'entity': 'Iraq', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.03068293'}
# {'entity': 'Iceland', 'date': ['1960'], 'relation': 'ISL', 'value': '73.42865854'}
# {'entity': 'Iceland', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '73.42865854'}
# {'entity': 'Israel', 'date': ['1960'], 'relation': 'ISR', 'value': ''}
# {'entity': 'Israel', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Italy', 'date': ['1960'], 'relation': 'ITA', 'value': '69.12390244'}
# {'entity': 'Italy', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.12390244'}
# {'entity': 'Jamaica', 'date': ['1960'], 'relation': 'JAM', 'value': '64.30807317'}
# {'entity': 'Jamaica', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '64.30807317'}
# {'entity': 'Jordan', 'date': ['1960'], 'relation': 'JOR', 'value': '52.68526829'}
# {'entity': 'Jordan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '52.68526829'}
# {'entity': 'Japan', 'date': ['1960'], 'relation': 'JPN', 'value': '67.66609756'}
# {'entity': 'Japan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.66609756'}
# {'entity': 'Kazakhstan', 'date': ['1960'], 'relation': 'KAZ', 'value': '58.36758537'}
# {'entity': 'Kazakhstan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '58.36758537'}
# {'entity': 'Kenya', 'date': ['1960'], 'relation': 'KEN', 'value': '46.36241463'}
# {'entity': 'Kenya', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.36241463'}
# {'entity': 'Kyrgyz Republic', 'date': ['1960'], 'relation': 'KGZ', 'value': '56.12807317'}
# {'entity': 'Kyrgyz Republic', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '56.12807317'}
# {'entity': 'Cambodia', 'date': ['1960'], 'relation': 'KHM', 'value': '41.23202439'}
# {'entity': 'Cambodia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.23202439'}
# {'entity': 'Kiribati', 'date': ['1960'], 'relation': 'KIR', 'value': '49.21597561'}
# {'entity': 'Kiribati', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '49.21597561'}
# {'entity': 'St. Kitts and Nevis', 'date': ['1960'], 'relation': 'KNA', 'value': ''}
# {'entity': 'St. Kitts and Nevis', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Korea, Rep.', 'date': ['1960'], 'relation': 'KOR', 'value': '53.00131707'}
# {'entity': 'Korea, Rep.', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '53.00131707'}
# {'entity': 'Kosovo', 'date': ['1960'], 'relation': 'KSV', 'value': ''}
# {'entity': 'Kosovo', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Kuwait', 'date': ['1960'], 'relation': 'KWT', 'value': '60.40019512'}
# {'entity': 'Kuwait', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.40019512'}
# {'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['1960'], 'relation': 'LAC', 'value': '55.65970176'}
# {'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '55.65970176'}
# {'entity': 'Lao PDR', 'date': ['1960'], 'relation': 'LAO', 'value': '43.20446341'}
# {'entity': 'Lao PDR', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '43.20446341'}
# {'entity': 'Lebanon', 'date': ['1960'], 'relation': 'LBN', 'value': '63.28012195'}
# {'entity': 'Lebanon', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '63.28012195'}
# {'entity': 'Liberia', 'date': ['1960'], 'relation': 'LBR', 'value': '34.78317073'}
# {'entity': 'Liberia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '34.78317073'}
# {'entity': 'Libya', 'date': ['1960'], 'relation': 'LBY', 'value': '42.64119512'}
# {'entity': 'Libya', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '42.64119512'}
# {'entity': 'St. Lucia', 'date': ['1960'], 'relation': 'LCA', 'value': '57.3037561'}
# {'entity': 'St. Lucia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '57.3037561'}
# {'entity': 'Latin America & Caribbean', 'date': ['1960'], 'relation': 'LCN', 'value': '56.04423306'}
# {'entity': 'Latin America & Caribbean', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '56.04423306'}
# {'entity': 'Least developed countries: UN classification', 'date': ['1960'], 'relation': 'LDC', 'value': '40.23466945'}
# {'entity': 'Least developed countries: UN classification', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '40.23466945'}
# {'entity': 'Low income', 'date': ['1960'], 'relation': 'LIC', 'value': '39.06830368'}
# {'entity': 'Low income', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '39.06830368'}
# {'entity': 'Liechtenstein', 'date': ['1960'], 'relation': 'LIE', 'value': ''}
# {'entity': 'Liechtenstein', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Sri Lanka', 'date': ['1960'], 'relation': 'LKA', 'value': '59.74714634'}
# {'entity': 'Sri Lanka', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '59.74714634'}
# {'entity': 'Lower middle income', 'date': ['1960'], 'relation': 'LMC', 'value': '45.55721406'}
# {'entity': 'Lower middle income', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.55721406'}
# {'entity': 'Low & middle income', 'date': ['1960'], 'relation': 'LMY', 'value': '47.14179034'}
# {'entity': 'Low & middle income', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '47.14179034'}
# {'entity': 'Lesotho', 'date': ['1960'], 'relation': 'LSO', 'value': '46.51070732'}
# {'entity': 'Lesotho', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.51070732'}
# {'entity': 'Late-demographic dividend', 'date': ['1960'], 'relation': 'LTE', 'value': '50.0342492'}
# {'entity': 'Late-demographic dividend', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '50.0342492'}
# {'entity': 'Lithuania', 'date': ['1960'], 'relation': 'LTU', 'value': '69.84731707'}
# {'entity': 'Lithuania', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.84731707'}
# {'entity': 'Luxembourg', 'date': ['1960'], 'relation': 'LUX', 'value': '68.44639024'}
# {'entity': 'Luxembourg', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.44639024'}
# {'entity': 'Latvia', 'date': ['1960'], 'relation': 'LVA', 'value': '69.78682927'}
# {'entity': 'Latvia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.78682927'}
# {'entity': 'Macao SAR, China', 'date': ['1960'], 'relation': 'MAC', 'value': '64.66092683'}
# {'entity': 'Macao SAR, China', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '64.66092683'}
# {'entity': 'St. Martin (French part)', 'date': ['1960'], 'relation': 'MAF', 'value': ''}
# {'entity': 'St. Martin (French part)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Morocco', 'date': ['1960'], 'relation': 'MAR', 'value': '48.44663415'}
# {'entity': 'Morocco', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.44663415'}
# {'entity': 'Monaco', 'date': ['1960'], 'relation': 'MCO', 'value': ''}
# {'entity': 'Monaco', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Moldova', 'date': ['1960'], 'relation': 'MDA', 'value': '61.81278049'}
# {'entity': 'Moldova', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '61.81278049'}
# {'entity': 'Madagascar', 'date': ['1960'], 'relation': 'MDG', 'value': '39.97468293'}
# {'entity': 'Madagascar', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '39.97468293'}
# {'entity': 'Maldives', 'date': ['1960'], 'relation': 'MDV', 'value': '37.26863415'}
# {'entity': 'Maldives', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '37.26863415'}
# {'entity': 'Middle East & North Africa', 'date': ['1960'], 'relation': 'MEA', 'value': '46.71603758'}
# {'entity': 'Middle East & North Africa', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.71603758'}
# {'entity': 'Mexico', 'date': ['1960'], 'relation': 'MEX', 'value': '57.06563415'}
# {'entity': 'Mexico', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '57.06563415'}
# {'entity': 'Marshall Islands', 'date': ['1960'], 'relation': 'MHL', 'value': ''}
# {'entity': 'Marshall Islands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Middle income', 'date': ['1960'], 'relation': 'MIC', 'value': '47.73237477'}
# {'entity': 'Middle income', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '47.73237477'}
# {'entity': 'Macedonia, FYR', 'date': ['1960'], 'relation': 'MKD', 'value': '60.62280488'}
# {'entity': 'Macedonia, FYR', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.62280488'}
# {'entity': 'Mali', 'date': ['1960'], 'relation': 'MLI', 'value': '28.21160976'}
# {'entity': 'Mali', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '28.21160976'}
# {'entity': 'Malta', 'date': ['1960'], 'relation': 'MLT', 'value': '67.60178049'}
# {'entity': 'Malta', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.60178049'}
# {'entity': 'Myanmar', 'date': ['1960'], 'relation': 'MMR', 'value': '42.73639024'}
# {'entity': 'Myanmar', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '42.73639024'}
# {'entity': 'Middle East & North Africa (excluding high income)', 'date': ['1960'], 'relation': 'MNA', 'value': '46.65525319'}
# {'entity': 'Middle East & North Africa (excluding high income)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.65525319'}
# {'entity': 'Montenegro', 'date': ['1960'], 'relation': 'MNE', 'value': '63.70560976'}
# {'entity': 'Montenegro', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '63.70560976'}
# {'entity': 'Mongolia', 'date': ['1960'], 'relation': 'MNG', 'value': '48.36880488'}
# {'entity': 'Mongolia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.36880488'}
# {'entity': 'Northern Mariana Islands', 'date': ['1960'], 'relation': 'MNP', 'value': ''}
# {'entity': 'Northern Mariana Islands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Mozambique', 'date': ['1960'], 'relation': 'MOZ', 'value': '35.00370732'}
# {'entity': 'Mozambique', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '35.00370732'}
# {'entity': 'Mauritania', 'date': ['1960'], 'relation': 'MRT', 'value': '43.48309756'}
# {'entity': 'Mauritania', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '43.48309756'}
# {'entity': 'Mauritius', 'date': ['1960'], 'relation': 'MUS', 'value': '58.74521951'}
# {'entity': 'Mauritius', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '58.74521951'}
# {'entity': 'Malawi', 'date': ['1960'], 'relation': 'MWI', 'value': '37.77363415'}
# {'entity': 'Malawi', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '37.77363415'}
# {'entity': 'Malaysia', 'date': ['1960'], 'relation': 'MYS', 'value': '59.47534146'}
# {'entity': 'Malaysia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '59.47534146'}
# {'entity': 'North America', 'date': ['1960'], 'relation': 'NAC', 'value': '69.89360376'}
# {'entity': 'North America', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.89360376'}
# {'entity': 'Namibia', 'date': ['1960'], 'relation': 'NAM', 'value': '46.88039024'}
# {'entity': 'Namibia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.88039024'}
# {'entity': 'New Caledonia', 'date': ['1960'], 'relation': 'NCL', 'value': '58.63902439'}
# {'entity': 'New Caledonia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '58.63902439'}
# {'entity': 'Niger', 'date': ['1960'], 'relation': 'NER', 'value': '35.51504878'}
# {'entity': 'Niger', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '35.51504878'}
# {'entity': 'Nigeria', 'date': ['1960'], 'relation': 'NGA', 'value': '37.18295122'}
# {'entity': 'Nigeria', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '37.18295122'}
# {'entity': 'Nicaragua', 'date': ['1960'], 'relation': 'NIC', 'value': '46.99882927'}
# {'entity': 'Nicaragua', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.99882927'}
# {'entity': 'Netherlands', 'date': ['1960'], 'relation': 'NLD', 'value': '73.39268293'}
# {'entity': 'Netherlands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '73.39268293'}
# {'entity': 'Norway', 'date': ['1960'], 'relation': 'NOR', 'value': '73.5497561'}
# {'entity': 'Norway', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '73.5497561'}
# {'entity': 'Nepal', 'date': ['1960'], 'relation': 'NPL', 'value': '35.17082927'}
# {'entity': 'Nepal', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '35.17082927'}
# {'entity': 'Nauru', 'date': ['1960'], 'relation': 'NRU', 'value': ''}
# {'entity': 'Nauru', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'New Zealand', 'date': ['1960'], 'relation': 'NZL', 'value': '71.23658537'}
# {'entity': 'New Zealand', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '71.23658537'}
# {'entity': 'OECD members', 'date': ['1960'], 'relation': 'OED', 'value': '67.35055062'}
# {'entity': 'OECD members', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.35055062'}
# {'entity': 'Oman', 'date': ['1960'], 'relation': 'OMN', 'value': '42.66707317'}
# {'entity': 'Oman', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '42.66707317'}
# {'entity': 'Other small states', 'date': ['1960'], 'relation': 'OSS', 'value': '51.34193561'}
# {'entity': 'Other small states', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '51.34193561'}
# {'entity': 'Pakistan', 'date': ['1960'], 'relation': 'PAK', 'value': '45.29046341'}
# {'entity': 'Pakistan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.29046341'}
# {'entity': 'Panama', 'date': ['1960'], 'relation': 'PAN', 'value': '60.88170732'}
# {'entity': 'Panama', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '60.88170732'}
# {'entity': 'Peru', 'date': ['1960'], 'relation': 'PER', 'value': '47.69158537'}
# {'entity': 'Peru', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '47.69158537'}
# {'entity': 'Philippines', 'date': ['1960'], 'relation': 'PHL', 'value': '57.81192683'}
# {'entity': 'Philippines', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '57.81192683'}
# {'entity': 'Palau', 'date': ['1960'], 'relation': 'PLW', 'value': ''}
# {'entity': 'Palau', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Papua New Guinea', 'date': ['1960'], 'relation': 'PNG', 'value': '38.4622439'}
# {'entity': 'Papua New Guinea', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '38.4622439'}
# {'entity': 'Poland', 'date': ['1960'], 'relation': 'POL', 'value': '67.6804878'}
# {'entity': 'Poland', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '67.6804878'}
# {'entity': 'Pre-demographic dividend', 'date': ['1960'], 'relation': 'PRE', 'value': '38.84935547'}
# {'entity': 'Pre-demographic dividend', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '38.84935547'}
# {'entity': 'Puerto Rico', 'date': ['1960'], 'relation': 'PRI', 'value': '68.71960976'}
# {'entity': 'Puerto Rico', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.71960976'}
# {'entity': 'Korea, Dem. People_s Rep.', 'date': ['1960'], 'relation': 'PRK', 'value': '51.07717073'}
# {'entity': 'Korea, Dem. People_s Rep.', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '51.07717073'}
# {'entity': 'Portugal', 'date': ['1960'], 'relation': 'PRT', 'value': '62.80892683'}
# {'entity': 'Portugal', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '62.80892683'}
# {'entity': 'Paraguay', 'date': ['1960'], 'relation': 'PRY', 'value': '63.79370732'}
# {'entity': 'Paraguay', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '63.79370732'}
# {'entity': 'Pacific island small states', 'date': ['1960'], 'relation': 'PSS', 'value': '53.66998764'}
# {'entity': 'Pacific island small states', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '53.66998764'}
# {'entity': 'Post-demographic dividend', 'date': ['1960'], 'relation': 'PST', 'value': '68.72925194'}
# {'entity': 'Post-demographic dividend', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.72925194'}
# {'entity': 'French Polynesia', 'date': ['1960'], 'relation': 'PYF', 'value': '56.35704878'}
# {'entity': 'French Polynesia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '56.35704878'}
# {'entity': 'Qatar', 'date': ['1960'], 'relation': 'QAT', 'value': '61.20607317'}
# {'entity': 'Qatar', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '61.20607317'}
# {'entity': 'Romania', 'date': ['1960'], 'relation': 'ROU', 'value': '65.64243902'}
# {'entity': 'Romania', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '65.64243902'}
# {'entity': 'Russian Federation', 'date': ['1960'], 'relation': 'RUS', 'value': '66.05529268'}
# {'entity': 'Russian Federation', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '66.05529268'}
# {'entity': 'Rwanda', 'date': ['1960'], 'relation': 'RWA', 'value': '42.24929268'}
# {'entity': 'Rwanda', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '42.24929268'}
# {'entity': 'South Asia', 'date': ['1960'], 'relation': 'SAS', 'value': '41.9604585'}
# {'entity': 'South Asia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.9604585'}
# {'entity': 'Saudi Arabia', 'date': ['1960'], 'relation': 'SAU', 'value': '45.66626829'}
# {'entity': 'Saudi Arabia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.66626829'}
# {'entity': 'Sudan', 'date': ['1960'], 'relation': 'SDN', 'value': '48.18763415'}
# {'entity': 'Sudan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '48.18763415'}
# {'entity': 'Senegal', 'date': ['1960'], 'relation': 'SEN', 'value': '38.206'}
# {'entity': 'Senegal', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '38.206'}
# {'entity': 'Singapore', 'date': ['1960'], 'relation': 'SGP', 'value': '65.65982927'}
# {'entity': 'Singapore', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '65.65982927'}
# {'entity': 'Solomon Islands', 'date': ['1960'], 'relation': 'SLB', 'value': '49.38170732'}
# {'entity': 'Solomon Islands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '49.38170732'}
# {'entity': 'Sierra Leone', 'date': ['1960'], 'relation': 'SLE', 'value': '30.33153659'}
# {'entity': 'Sierra Leone', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '30.33153659'}
# {'entity': 'El Salvador', 'date': ['1960'], 'relation': 'SLV', 'value': '49.94792683'}
# {'entity': 'El Salvador', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '49.94792683'}
# {'entity': 'San Marino', 'date': ['1960'], 'relation': 'SMR', 'value': ''}
# {'entity': 'San Marino', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Somalia', 'date': ['1960'], 'relation': 'SOM', 'value': '36.96587805'}
# {'entity': 'Somalia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '36.96587805'}
# {'entity': 'Serbia', 'date': ['1960'], 'relation': 'SRB', 'value': ''}
# {'entity': 'Serbia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Sub-Saharan Africa (excluding high income)', 'date': ['1960'], 'relation': 'SSA', 'value': '40.1696773'}
# {'entity': 'Sub-Saharan Africa (excluding high income)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '40.1696773'}
# {'entity': 'South Sudan', 'date': ['1960'], 'relation': 'SSD', 'value': '31.67670732'}
# {'entity': 'South Sudan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '31.67670732'}
# {'entity': 'Sub-Saharan Africa', 'date': ['1960'], 'relation': 'SSF', 'value': '40.1696773'}
# {'entity': 'Sub-Saharan Africa', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '40.1696773'}
# {'entity': 'Small states', 'date': ['1960'], 'relation': 'SST', 'value': '54.6681411'}
# {'entity': 'Small states', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '54.6681411'}
# {'entity': 'Sao Tome and Principe', 'date': ['1960'], 'relation': 'STP', 'value': '50.45136585'}
# {'entity': 'Sao Tome and Principe', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '50.45136585'}
# {'entity': 'Suriname', 'date': ['1960'], 'relation': 'SUR', 'value': '59.68012195'}
# {'entity': 'Suriname', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '59.68012195'}
# {'entity': 'Slovak Republic', 'date': ['1960'], 'relation': 'SVK', 'value': '69.97592683'}
# {'entity': 'Slovak Republic', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '69.97592683'}
# {'entity': 'Slovenia', 'date': ['1960'], 'relation': 'SVN', 'value': '68.97804878'}
# {'entity': 'Slovenia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.97804878'}
# {'entity': 'Sweden', 'date': ['1960'], 'relation': 'SWE', 'value': '73.00560976'}
# {'entity': 'Sweden', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '73.00560976'}
# {'entity': 'Swaziland', 'date': ['1960'], 'relation': 'SWZ', 'value': '44.23378049'}
# {'entity': 'Swaziland', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '44.23378049'}
# {'entity': 'Sint Maarten (Dutch part)', 'date': ['1960'], 'relation': 'SXM', 'value': ''}
# {'entity': 'Sint Maarten (Dutch part)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Seychelles', 'date': ['1960'], 'relation': 'SYC', 'value': ''}
# {'entity': 'Seychelles', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Syrian Arab Republic', 'date': ['1960'], 'relation': 'SYR', 'value': '52.7682439'}
# {'entity': 'Syrian Arab Republic', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '52.7682439'}
# {'entity': 'Turks and Caicos Islands', 'date': ['1960'], 'relation': 'TCA', 'value': ''}
# {'entity': 'Turks and Caicos Islands', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Chad', 'date': ['1960'], 'relation': 'TCD', 'value': '38.01612195'}
# {'entity': 'Chad', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '38.01612195'}
# {'entity': 'East Asia & Pacific (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'TEA', 'value': '45.39404114'}
# {'entity': 'East Asia & Pacific (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.39404114'}
# {'entity': 'Europe & Central Asia (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'TEC', 'value': '63.82034154'}
# {'entity': 'Europe & Central Asia (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '63.82034154'}
# {'entity': 'Togo', 'date': ['1960'], 'relation': 'TGO', 'value': '40.27282927'}
# {'entity': 'Togo', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '40.27282927'}
# {'entity': 'Thailand', 'date': ['1960'], 'relation': 'THA', 'value': '54.69931707'}
# {'entity': 'Thailand', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '54.69931707'}
# {'entity': 'Tajikistan', 'date': ['1960'], 'relation': 'TJK', 'value': '56.15353659'}
# {'entity': 'Tajikistan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '56.15353659'}
# {'entity': 'Turkmenistan', 'date': ['1960'], 'relation': 'TKM', 'value': '54.45868293'}
# {'entity': 'Turkmenistan', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '54.45868293'}
# {'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'TLA', 'value': '55.62310291'}
# {'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '55.62310291'}
# {'entity': 'Middle East & North Africa (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'TMN', 'value': '46.65525319'}
# {'entity': 'Middle East & North Africa (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '46.65525319'}
# {'entity': 'Timor-Leste', 'date': ['1960'], 'relation': 'TLS', 'value': '33.73712195'}
# {'entity': 'Timor-Leste', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '33.73712195'}
# {'entity': 'Tonga', 'date': ['1960'], 'relation': 'TON', 'value': '61.36453659'}
# {'entity': 'Tonga', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '61.36453659'}
# {'entity': 'South Asia (IDA & IBRD)', 'date': ['1960'], 'relation': 'TSA', 'value': '41.9604585'}
# {'entity': 'South Asia (IDA & IBRD)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '41.9604585'}
# {'entity': 'Sub-Saharan Africa (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'TSS', 'value': '40.1696773'}
# {'entity': 'Sub-Saharan Africa (IDA & IBRD countries)', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '40.1696773'}
# {'entity': 'Trinidad and Tobago', 'date': ['1960'], 'relation': 'TTO', 'value': '62.65758537'}
# {'entity': 'Trinidad and Tobago', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '62.65758537'}
# {'entity': 'Tunisia', 'date': ['1960'], 'relation': 'TUN', 'value': '42.0097561'}
# {'entity': 'Tunisia', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '42.0097561'}
# {'entity': 'Turkey', 'date': ['1960'], 'relation': 'TUR', 'value': '45.38441463'}
# {'entity': 'Turkey', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '45.38441463'}
# {'entity': 'Tuvalu', 'date': ['1960'], 'relation': 'TUV', 'value': ''}
# {'entity': 'Tuvalu', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Tanzania', 'date': ['1960'], 'relation': 'TZA', 'value': '43.65387805'}
# {'entity': 'Tanzania', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '43.65387805'}
# {'entity': 'Uganda', 'date': ['1960'], 'relation': 'UGA', 'value': '43.98356098'}
# {'entity': 'Uganda', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '43.98356098'}
# {'entity': 'Ukraine', 'date': ['1960'], 'relation': 'UKR', 'value': '68.29953659'}
# {'entity': 'Ukraine', 'date': ['1960'], 'relation': 'Life expectancy at birth', 'value': '68.29953659'}
# ...
# {'entity': 'Peru', 'date': ['2014'], 'relation': 'PER', 'value': '74.52553659'}
# {'entity': 'Peru', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.52553659'}
# {'entity': 'Philippines', 'date': ['2014'], 'relation': 'PHL', 'value': '68.26563415'}
# {'entity': 'Philippines', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '68.26563415'}
# {'entity': 'Palau', 'date': ['2014'], 'relation': 'PLW', 'value': ''}
# {'entity': 'Palau', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Papua New Guinea', 'date': ['2014'], 'relation': 'PNG', 'value': '62.60692683'}
# {'entity': 'Papua New Guinea', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '62.60692683'}
# {'entity': 'Poland', 'date': ['2014'], 'relation': 'POL', 'value': '77.25365854'}
# {'entity': 'Poland', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '77.25365854'}
# {'entity': 'Pre-demographic dividend', 'date': ['2014'], 'relation': 'PRE', 'value': '58.36457966'}
# {'entity': 'Pre-demographic dividend', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '58.36457966'}
# {'entity': 'Puerto Rico', 'date': ['2014'], 'relation': 'PRI', 'value': '79.37473171'}
# {'entity': 'Puerto Rico', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '79.37473171'}
# {'entity': 'Korea, Dem. People_s Rep.', 'date': ['2014'], 'relation': 'PRK', 'value': '70.07468293'}
# {'entity': 'Korea, Dem. People_s Rep.', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '70.07468293'}
# {'entity': 'Portugal', 'date': ['2014'], 'relation': 'PRT', 'value': '80.72195122'}
# {'entity': 'Portugal', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '80.72195122'}
# {'entity': 'Paraguay', 'date': ['2014'], 'relation': 'PRY', 'value': '72.92170732'}
# {'entity': 'Paraguay', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '72.92170732'}
# {'entity': 'Pacific island small states', 'date': ['2014'], 'relation': 'PSS', 'value': '69.91903222'}
# {'entity': 'Pacific island small states', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '69.91903222'}
# {'entity': 'Post-demographic dividend', 'date': ['2014'], 'relation': 'PST', 'value': '80.47215977'}
# {'entity': 'Post-demographic dividend', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '80.47215977'}
# {'entity': 'French Polynesia', 'date': ['2014'], 'relation': 'PYF', 'value': '76.54168293'}
# {'entity': 'French Polynesia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '76.54168293'}
# {'entity': 'Qatar', 'date': ['2014'], 'relation': 'QAT', 'value': '78.59680488'}
# {'entity': 'Qatar', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '78.59680488'}
# {'entity': 'Romania', 'date': ['2014'], 'relation': 'ROU', 'value': '75.06341463'}
# {'entity': 'Romania', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '75.06341463'}
# {'entity': 'Russian Federation', 'date': ['2014'], 'relation': 'RUS', 'value': '70.36585366'}
# {'entity': 'Russian Federation', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '70.36585366'}
# {'entity': 'Rwanda', 'date': ['2014'], 'relation': 'RWA', 'value': '63.96565854'}
# {'entity': 'Rwanda', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '63.96565854'}
# {'entity': 'South Asia', 'date': ['2014'], 'relation': 'SAS', 'value': '68.1210446'}
# {'entity': 'South Asia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '68.1210446'}
# {'entity': 'Saudi Arabia', 'date': ['2014'], 'relation': 'SAU', 'value': '74.33721951'}
# {'entity': 'Saudi Arabia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.33721951'}
# {'entity': 'Sudan', 'date': ['2014'], 'relation': 'SDN', 'value': '63.45853659'}
# {'entity': 'Sudan', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '63.45853659'}
# {'entity': 'Senegal', 'date': ['2014'], 'relation': 'SEN', 'value': '66.37258537'}
# {'entity': 'Senegal', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '66.37258537'}
# {'entity': 'Singapore', 'date': ['2014'], 'relation': 'SGP', 'value': '82.64634146'}
# {'entity': 'Singapore', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '82.64634146'}
# {'entity': 'Solomon Islands', 'date': ['2014'], 'relation': 'SLB', 'value': '67.93080488'}
# {'entity': 'Solomon Islands', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '67.93080488'}
# {'entity': 'Sierra Leone', 'date': ['2014'], 'relation': 'SLE', 'value': '50.87878049'}
# {'entity': 'Sierra Leone', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '50.87878049'}
# {'entity': 'El Salvador', 'date': ['2014'], 'relation': 'SLV', 'value': '72.75456098'}
# {'entity': 'El Salvador', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '72.75456098'}
# {'entity': 'San Marino', 'date': ['2014'], 'relation': 'SMR', 'value': ''}
# {'entity': 'San Marino', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Somalia', 'date': ['2014'], 'relation': 'SOM', 'value': '55.35480488'}
# {'entity': 'Somalia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '55.35480488'}
# {'entity': 'Serbia', 'date': ['2014'], 'relation': 'SRB', 'value': '75.53414634'}
# {'entity': 'Serbia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '75.53414634'}
# {'entity': 'Sub-Saharan Africa (excluding high income)', 'date': ['2014'], 'relation': 'SSA', 'value': '58.55747868'}
# {'entity': 'Sub-Saharan Africa (excluding high income)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '58.55747868'}
# {'entity': 'South Sudan', 'date': ['2014'], 'relation': 'SSD', 'value': '55.68221951'}
# {'entity': 'South Sudan', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '55.68221951'}
# {'entity': 'Sub-Saharan Africa', 'date': ['2014'], 'relation': 'SSF', 'value': '58.55885496'}
# {'entity': 'Sub-Saharan Africa', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '58.55885496'}
# {'entity': 'Small states', 'date': ['2014'], 'relation': 'SST', 'value': '67.83853586'}
# {'entity': 'Small states', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '67.83853586'}
# {'entity': 'Sao Tome and Principe', 'date': ['2014'], 'relation': 'STP', 'value': '66.38460976'}
# {'entity': 'Sao Tome and Principe', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '66.38460976'}
# {'entity': 'Suriname', 'date': ['2014'], 'relation': 'SUR', 'value': '71.15143902'}
# {'entity': 'Suriname', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '71.15143902'}
# {'entity': 'Slovak Republic', 'date': ['2014'], 'relation': 'SVK', 'value': '76.71463415'}
# {'entity': 'Slovak Republic', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '76.71463415'}
# {'entity': 'Slovenia', 'date': ['2014'], 'relation': 'SVN', 'value': '80.5195122'}
# {'entity': 'Slovenia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '80.5195122'}
# {'entity': 'Sweden', 'date': ['2014'], 'relation': 'SWE', 'value': '81.95609756'}
# {'entity': 'Sweden', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '81.95609756'}
# {'entity': 'Swaziland', 'date': ['2014'], 'relation': 'SWZ', 'value': '48.93473171'}
# {'entity': 'Swaziland', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '48.93473171'}
# {'entity': 'Sint Maarten (Dutch part)', 'date': ['2014'], 'relation': 'SXM', 'value': ''}
# {'entity': 'Sint Maarten (Dutch part)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Seychelles', 'date': ['2014'], 'relation': 'SYC', 'value': '73.22926829'}
# {'entity': 'Seychelles', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '73.22926829'}
# {'entity': 'Syrian Arab Republic', 'date': ['2014'], 'relation': 'SYR', 'value': '70.07102439'}
# {'entity': 'Syrian Arab Republic', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '70.07102439'}
# {'entity': 'Turks and Caicos Islands', 'date': ['2014'], 'relation': 'TCA', 'value': ''}
# {'entity': 'Turks and Caicos Islands', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Chad', 'date': ['2014'], 'relation': 'TCD', 'value': '51.55580488'}
# {'entity': 'Chad', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '51.55580488'}
# {'entity': 'East Asia & Pacific (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'TEA', 'value': '74.034774'}
# {'entity': 'East Asia & Pacific (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.034774'}
# {'entity': 'Europe & Central Asia (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'TEC', 'value': '72.39720521'}
# {'entity': 'Europe & Central Asia (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '72.39720521'}
# {'entity': 'Togo', 'date': ['2014'], 'relation': 'TGO', 'value': '59.65580488'}
# {'entity': 'Togo', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '59.65580488'}
# {'entity': 'Thailand', 'date': ['2014'], 'relation': 'THA', 'value': '74.42202439'}
# {'entity': 'Thailand', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.42202439'}
# {'entity': 'Tajikistan', 'date': ['2014'], 'relation': 'TJK', 'value': '69.59797561'}
# {'entity': 'Tajikistan', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '69.59797561'}
# {'entity': 'Turkmenistan', 'date': ['2014'], 'relation': 'TKM', 'value': '65.59853659'}
# {'entity': 'Turkmenistan', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '65.59853659'}
# {'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'TLA', 'value': '74.83097562'}
# {'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.83097562'}
# {'entity': 'Middle East & North Africa (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'TMN', 'value': '72.2596293'}
# {'entity': 'Middle East & North Africa (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '72.2596293'}
# {'entity': 'Timor-Leste', 'date': ['2014'], 'relation': 'TLS', 'value': '68.25914634'}
# {'entity': 'Timor-Leste', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '68.25914634'}
# {'entity': 'Tonga', 'date': ['2014'], 'relation': 'TON', 'value': '72.79219512'}
# {'entity': 'Tonga', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '72.79219512'}
# {'entity': 'South Asia (IDA & IBRD)', 'date': ['2014'], 'relation': 'TSA', 'value': '68.1210446'}
# {'entity': 'South Asia (IDA & IBRD)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '68.1210446'}
# {'entity': 'Sub-Saharan Africa (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'TSS', 'value': '58.55885496'}
# {'entity': 'Sub-Saharan Africa (IDA & IBRD countries)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '58.55885496'}
# {'entity': 'Trinidad and Tobago', 'date': ['2014'], 'relation': 'TTO', 'value': '70.44056098'}
# {'entity': 'Trinidad and Tobago', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '70.44056098'}
# {'entity': 'Tunisia', 'date': ['2014'], 'relation': 'TUN', 'value': '74.14390244'}
# {'entity': 'Tunisia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.14390244'}
# {'entity': 'Turkey', 'date': ['2014'], 'relation': 'TUR', 'value': '75.1635122'}
# {'entity': 'Turkey', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '75.1635122'}
# {'entity': 'Tuvalu', 'date': ['2014'], 'relation': 'TUV', 'value': ''}
# {'entity': 'Tuvalu', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Tanzania', 'date': ['2014'], 'relation': 'TZA', 'value': '64.94390244'}
# {'entity': 'Tanzania', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '64.94390244'}
# {'entity': 'Uganda', 'date': ['2014'], 'relation': 'UGA', 'value': '58.46641463'}
# {'entity': 'Uganda', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '58.46641463'}
# {'entity': 'Ukraine', 'date': ['2014'], 'relation': 'UKR', 'value': '71.18658537'}
# {'entity': 'Ukraine', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '71.18658537'}
# {'entity': 'Upper middle income', 'date': ['2014'], 'relation': 'UMC', 'value': '74.43883867'}
# {'entity': 'Upper middle income', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.43883867'}
# {'entity': 'Uruguay', 'date': ['2014'], 'relation': 'URY', 'value': '76.98614634'}
# {'entity': 'Uruguay', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '76.98614634'}
# {'entity': 'United States', 'date': ['2014'], 'relation': 'USA', 'value': '78.94146341'}
# {'entity': 'United States', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '78.94146341'}
# {'entity': 'Uzbekistan', 'date': ['2014'], 'relation': 'UZB', 'value': '68.33902439'}
# {'entity': 'Uzbekistan', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '68.33902439'}
# {'entity': 'St. Vincent and the Grenadines', 'date': ['2014'], 'relation': 'VCT', 'value': '72.93685366'}
# {'entity': 'St. Vincent and the Grenadines', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '72.93685366'}
# {'entity': 'Venezuela, RB', 'date': ['2014'], 'relation': 'VEN', 'value': '74.23619512'}
# {'entity': 'Venezuela, RB', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '74.23619512'}
# {'entity': 'British Virgin Islands', 'date': ['2014'], 'relation': 'VGB', 'value': ''}
# {'entity': 'British Virgin Islands', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': ''}
# {'entity': 'Virgin Islands (U.S.)', 'date': ['2014'], 'relation': 'VIR', 'value': '79.77317073'}
# {'entity': 'Virgin Islands (U.S.)', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '79.77317073'}
# {'entity': 'Vietnam', 'date': ['2014'], 'relation': 'VNM', 'value': '75.62912195'}
# {'entity': 'Vietnam', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '75.62912195'}
# {'entity': 'Vanuatu', 'date': ['2014'], 'relation': 'VUT', 'value': '71.91831707'}
# {'entity': 'Vanuatu', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '71.91831707'}
# {'entity': 'West Bank and Gaza', 'date': ['2014'], 'relation': 'PSE', 'value': '72.90402439'}
# {'entity': 'West Bank and Gaza', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '72.90402439'}
# {'entity': 'World', 'date': ['2014'], 'relation': 'WLD', 'value': '71.45499816'}
# {'entity': 'World', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '71.45499816'}
# {'entity': 'Samoa', 'date': ['2014'], 'relation': 'WSM', 'value': '73.51182927'}
# {'entity': 'Samoa', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '73.51182927'}
# {'entity': 'Yemen, Rep.', 'date': ['2014'], 'relation': 'YEM', 'value': '63.81819512'}
# {'entity': 'Yemen, Rep.', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '63.81819512'}
# {'entity': 'South Africa', 'date': ['2014'], 'relation': 'ZAF', 'value': '57.18212195'}
# {'entity': 'South Africa', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '57.18212195'}
# {'entity': 'Congo, Dem. Rep.', 'date': ['2014'], 'relation': 'COD', 'value': '58.65919512'}
# {'entity': 'Congo, Dem. Rep.', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '58.65919512'}
# {'entity': 'Zambia', 'date': ['2014'], 'relation': 'ZMB', 'value': '60.04704878'}
# {'entity': 'Zambia', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '60.04704878'}
# {'entity': 'Zimbabwe', 'date': ['2014'], 'relation': 'ZWE', 'value': '57.49831707'}
# {'entity': 'Zimbabwe', 'date': ['2014'], 'relation': 'Life expectancy at birth', 'value': '57.49831707'}
