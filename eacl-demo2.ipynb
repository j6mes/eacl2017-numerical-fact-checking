# %% [markdown]
# # Numerical Fact Checking System. Univeristy of Sheffield
#
# Pre-requisites:
#  * Gradle
#  * Java jdk8
#  * Python 3
#   * numpy
#   * jnius
#   * fuzzywuzzy
#   * sklearn
#   * urllib3

# %% [markdown]
# ## Configuration
# This defines the colleciton of tables that is used to populate the knowledge base

# %%
world = "herox"

# %% [markdown]
# ## Common setup
#
# Import required dependencies and download/install Stanford CoreNLP

# %%
import sys
import os
import re

#Set path manually to incldue sources location
if 'src/' not in sys.path:
    sys.path.append('src/')

# %% [markdown]
# If the following step fails. Run `gradlew writeClasspath` on the terminal in this folder. Then try again

# %%
#Load Java classpath for stanford corenlp using gradle. this will also install it if missing
from subprocess import run,PIPE
if 'CLASSPATH' not in os.environ:
    if not (os.path.exists('build') and os.path.exists('build/classpath.txt')):
        print("Generating classpath")
        r=run(["./gradlew", "writeClasspath"],stdout=PIPE, stderr=PIPE, universal_newlines=True)
        print(r.stdout)
        print(r.stderr)
              
    print("Loading classpath")
    os.environ['CLASSPATH'] = open('build/classpath.txt','r').read()
    print("Done")
# Out:
# Loading classpath
# Done

# %% [markdown]
# ## Fact Checking
#
# ### Training
# Load Modules for fact checking, generate the features and train our classifier from our training data

# %%
from classifier.Classifier import Classifier
from classifier.LogisticRegressionClassifier import LogisticRegressionClassifier
from classifier.features.generate_features import FeatureGenerator, num, is_num
from distant_supervision.utterance_detection import f_threshold_match
from factchecking.question import Question
from tabular.filtering import load_collection
# Out:
# /Users/james/anaconda/lib/python3.5/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
fg = FeatureGenerator()
Xs,ys = fg.generate_training(world)
# Out:
# Done: 0.0
# Search for ”Exxon Mobil" Market Value
# Query already executed
# Done: 6.25
# Search for "Unaccompanied children" claimed asylum
# Query already executed
# Done: 12.5
# Search for "Hamas" Founded
# Query already executed
# Done: 18.75
# Search for "United States" Average Temperature
# Query already executed
# Done: 25.0
# Search for "United States" Life expectancy
# Query already executed
# Done: 31.25
# Search for "United States" Number of abortions
# Query already executed
# Done: 37.5
# Search for "United States" Abortion Rate per 1,000 births
# Query already executed
# Done: 43.75
# Search for "United States Teenagers" Percentage Enrolled in education
# Query already executed
# Done: 50.0
# Search for "United States Teenagers" Enrolled in education
# Query already executed
# Done: 56.25
# Search for "America" bee colonies 2011
# Query already executed
# Done: 62.5
# Search for "United States" Financial Intermediary Funds 2016
# Query already executed
# Done: 68.75
# Search for "United States" Homocides by firearm
# Query already executed
# Done: 75.0
# Search for "United Kingdom" Educated at grammar schools 2016
# Query already executed
# Done: 81.25
# Search for "USA" Measles Vaccination Rate
# Query already executed
# Done: 87.5
# Search for "USA" Practicing doctors per 1000
# Query already executed
# Done: 93.75
# Search for "USA" Daily Smokers 2014
# Query already executed
# Registering + words in BOW
# Registering - words in BOW
# Registering columns
# Counting features
# Total positive: 34
# Total negative: 2116
# Looking for positive features
# 0
# Subsampling negative features
# 0

# %%
classifier = LogisticRegressionClassifier()
classifier.train(Xs,ys)
# Out:
# Training classifier 3
# Trained

# %% [markdown]
# ### Runtime
#
# Load the source data

# %%
tables = load_collection(world)
print(tables.files)
# Out:
# LOADED:
# [{'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/1.tsv', 'id': 'hx-0'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/2.tsv', 'id': 'hx-1'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/3.tsv', 'id': 'hx-2'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/4.tsv', 'id': 'hx-3'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/5.tsv', 'id': 'hx-4'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/8.tsv', 'id': 'hx-5'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/9.tsv', 'id': 'hx-6'}, {'answer': '0', 'utterance': 'No Utterance', 'table': 'herox/10.tsv', 'id': 'hx-7'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/11.tsv', 'id': 'hx-8'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/12.tsv', 'id': 'hx-9'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/13.tsv', 'id': 'hx-10'}, {'answer': '0', 'utterance': 'N', 'table': 'herox/14.tsv', 'id': 'hx-11'}]
# register table herox/1.tsv
# register table herox/2.tsv
# register table herox/3.tsv
# register table herox/4.tsv
# register table herox/5.tsv
# register table herox/8.tsv
# register table herox/9.tsv
# register table herox/10.tsv
# register table herox/11.tsv
# register table herox/12.tsv
# register table herox/13.tsv
# register table herox/14.tsv
# {'herox/14.tsv', 'herox/9.tsv', 'herox/1.tsv', 'herox/11.tsv', 'herox/8.tsv', 'herox/5.tsv', 'herox/4.tsv', 'herox/12.tsv', 'herox/2.tsv', 'herox/10.tsv', 'herox/13.tsv', 'herox/3.tsv'}

# %% [markdown]
# Define the fact checking function

# %%
def fact_check(q):
    question = Question(text=q, type="NUM")
    question.parse()
    tuples,q_features = fg.generate_test(tables,question)
    q_match = False
    
  
    
    if len(tuples)>0:
  
    
        
        
        q_predicted = classifier.predict(q_features)

        for i in range(len(tuples)):
            tuple = tuples[i]
            
            skip = False
            if 'date' in tuple[1].keys() and len(question.dates):
                for date in question.dates:
                    dstrs = set()
                    for d in question.dates:
                        dstrs.add(str(d))
                    if not len(set(tuple[1]['date']).intersection(dstrs)):
                        skip = True
                        
            if skip:
                continue
    

            if is_num(tuple[1]['value']):
                prediction = q_predicted[0][i]
                features = q_features[i]

                
             
                if prediction == 1:
                    print(str(tuple) + "\t\t" + ("Possible Match" if prediction else "No match"))
                    for number in question.numbers:
                        value = num(tuple[1]['value'])

                        if value is None:
                            continue

                        if f_threshold_match(number, value, 0.05):
                            print(str(tuple) + "\t\t" + "Threshold Match to 5%")
                            q_match = True

                    for number in question.dates:
                        value = num(tuple[1]['value'])
                        if number == value:
                            print(str(tuple) + "\t\t" + "Exact Match")
                            q_match = True
        print(question.text)
        print(q_match)

    else:
        print(question.text)
        print("No supporting information can be found in the knowledge base")
    print("\n\n")

# %% [markdown]
# # Fact checking

# %%
fact_check("Around 22250 unaccompanied children claimed asylum in Germany in 2015")
fact_check("Around 4500 unaccompanied children claimed asylum in Germany in 2014")
fact_check("There were 4500 immigrants in Germany in 2014")


fact_check("97% of children in America were vaccinated against measles in 2014.")
fact_check("12.9% of the total population of the USA were daily smokers in 2014")
fact_check("In the USA in 2010, the number of homicides by firearm was almost 10,000.")
fact_check("In the USA in 2010, the number of homicides by firearm was almost 11,000.")
fact_check("In 2012 there were 3,282,570 bee colonies in America. ")
# Out:
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '22255', 'entity': 'Germany', 'date': ['2015']})		Threshold Match to 5%
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# Around 22250 unaccompanied children claimed asylum in Germany in 2015
# True
#
#
#
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# Around 4500 unaccompanied children claimed asylum in Germany in 2014
# True
#
#
#
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/2.tsv', {'relation': 'Asylum applicants considered to be unaccompanied minors', 'value': '4400', 'entity': 'Germany', 'date': ['2014']})		Threshold Match to 5%
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'DEU', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.84390244', 'entity': 'Germany', 'date': ['2014']})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '4846021517', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '161', 'entity': 'Germany'})		Possible Match
# There were 4500 immigrants in Germany in 2014
# True
#
#
#
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.71736292', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.71736292', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.71736292', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.71736292', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.94196452', 'entity': 'Latin America & Caribbean', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.94196452', 'entity': 'Latin America & Caribbean', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.94196452', 'entity': 'Latin America & Caribbean', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.94196452', 'entity': 'Latin America & Caribbean', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.24410183', 'entity': 'North America', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.24410183', 'entity': 'North America', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.24410183', 'entity': 'North America', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.24410183', 'entity': 'North America', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Threshold Match to 5%
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Threshold Match to 5%
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Threshold Match to 5%
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Threshold Match to 5%
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# 97% of children in America were vaccinated against measles in 2014.
# True
#
#
#
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '75.23365854', 'entity': 'Bahamas, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '75.23365854', 'entity': 'Bahamas, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '75.23365854', 'entity': 'Bahamas, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '75.23365854', 'entity': 'Bahamas, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '76.56332725', 'entity': 'Central Europe and the Baltics', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '76.56332725', 'entity': 'Central Europe and the Baltics', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '76.56332725', 'entity': 'Central Europe and the Baltics', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '76.56332725', 'entity': 'Central Europe and the Baltics', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '60.22843902', 'entity': 'Gambia, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '60.22843902', 'entity': 'Gambia, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '60.22843902', 'entity': 'Gambia, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '60.22843902', 'entity': 'Gambia, The', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.75320031', 'entity': 'IDA & IBRD total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.75320031', 'entity': 'IDA & IBRD total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.75320031', 'entity': 'IDA & IBRD total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.75320031', 'entity': 'IDA & IBRD total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '63.33352118', 'entity': 'IDA total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '63.33352118', 'entity': 'IDA total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '63.33352118', 'entity': 'IDA total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '63.33352118', 'entity': 'IDA total', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.83097562', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.93685366', 'entity': 'St. Vincent and the Grenadines', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.93685366', 'entity': 'St. Vincent and the Grenadines', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.93685366', 'entity': 'St. Vincent and the Grenadines', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.93685366', 'entity': 'St. Vincent and the Grenadines', 'date': ['2014']})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.36817073', 'entity': 'United Arab Emirates', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.84469981', 'entity': 'Caribbean small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '81.05609756', 'entity': 'United Kingdom', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '66.4473324', 'entity': 'Other small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.91903222', 'entity': 'Pacific island small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.83853586', 'entity': 'Small states', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.94146341', 'entity': 'United States', 'date': ['2014']})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Weight (%)', 'value': '2.17', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Price', 'value': '20.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Shares', 'value': '12,423,103.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ...
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Market Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'Notional Value', 'value': '248,462,060.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/1.tsv', {'relation': 'SEDOL', 'value': '2,295,677.00', 'entity': 'BANK OF AMERICA CORP'})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.26486374', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.26486374', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.26486374', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.26486374', 'entity': 'Latin America & Caribbean (excluding high income)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.48749666', 'entity': 'Latin America & Caribbean', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.48749666', 'entity': 'Latin America & Caribbean', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.48749666', 'entity': 'Latin America & Caribbean', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.48749666', 'entity': 'Latin America & Caribbean', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.02297105', 'entity': 'North America', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.02297105', 'entity': 'North America', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.02297105', 'entity': 'North America', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '79.02297105', 'entity': 'North America', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.37018061', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.37018061', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.37018061', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '74.37018061', 'entity': 'Latin America & the Caribbean (IDA & IBRD countries)', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.02414634', 'entity': 'United Arab Emirates', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.02414634', 'entity': 'United Arab Emirates', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.02414634', 'entity': 'United Arab Emirates', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '77.02414634', 'entity': 'United Arab Emirates', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.54548474', 'entity': 'Caribbean small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.54548474', 'entity': 'Caribbean small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.54548474', 'entity': 'Caribbean small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '72.54548474', 'entity': 'Caribbean small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.90487805', 'entity': 'United Kingdom', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.90487805', 'entity': 'United Kingdom', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.90487805', 'entity': 'United Kingdom', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '80.90487805', 'entity': 'United Kingdom', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '65.9447555', 'entity': 'Other small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '65.9447555', 'entity': 'Other small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '65.9447555', 'entity': 'Other small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '65.9447555', 'entity': 'Other small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.53548143', 'entity': 'Pacific island small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.53548143', 'entity': 'Pacific island small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.53548143', 'entity': 'Pacific island small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '69.53548143', 'entity': 'Pacific island small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.40800894', 'entity': 'Small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.40800894', 'entity': 'Small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.40800894', 'entity': 'Small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '67.40800894', 'entity': 'Small states', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.74146341', 'entity': 'United States', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.74146341', 'entity': 'United States', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.74146341', 'entity': 'United States', 'date': ['2012']})		Possible Match
# ('herox/5.tsv', {'relation': 'Life expectancy at birth', 'value': '78.74146341', 'entity': 'United States', 'date': ['2012']})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '1000000', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '8562267609', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': ' Value Contributed', 'value': '13404343684', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Name', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '1', 'entity': 'United Arab Emirates'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '208', 'entity': 'United Kingdom'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/9.tsv', {'relation': 'Count of Donor Country Code2', 'value': '230', 'entity': 'United States'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Diptheria, Tetanus, Pertussis', 'value': '84.2', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Polio', 'value': '93.3', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/14.tsv', {'relation': 'Measles, Mumps, Rubella', 'value': '91.5', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/13.tsv', {'relation': 'Percentage Daily Smokers', 'value': '16.8', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# ('herox/11.tsv', {'relation': 'Firearm', 'value': '11078', 'entity': 'USA'})		Possible Match
# In 2012 there were 3,282,570 bee colonies in America.
# False
